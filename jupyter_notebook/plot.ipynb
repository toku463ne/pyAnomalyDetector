# %%
import sys,os
sys.path.append(os.path.join(os.getcwd(), '..'))
from utils.data_generator import *

#data = sine_wave(0,10,100,5)
#data = convex_wave(0,10,100,noise_rate=0.01)
data = stairs_wave(0,10,100,5,noise_rate=0.1,inverse=True)

plot_wave(data)
