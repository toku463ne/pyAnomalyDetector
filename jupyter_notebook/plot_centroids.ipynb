# %%
import sys, os
sys.path.append(os.path.join(os.getcwd(), '..'))
import utils.kmeans as kmeans

plotfile = os.path.join(os.environ['HOME'], 'anomdectests/centroids/1743291154.json.gz')

centroids = kmeans.load_centroids(plotfile)
#print(centroids)
#kmeans.plot_heatmap(centroids)
kmeans.plot_heatmap(centroids, 30)

# %%
centroids, old_new_mapping = kmeans.rearange_centroids(centroids, 0.05)
print(old_new_mapping)
#kmeans.plot_heatmap(centroids)
kmeans.plot_heatmap(centroids)
# Out:
# {10: 0, 3: 1, 5: 2, 11: 3, 13: 4, 17: 5, 23: 6, 36: 7, 8: 8}
