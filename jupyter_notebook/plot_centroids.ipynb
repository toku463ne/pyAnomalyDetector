# %%
import sys, os
sys.path.append(os.path.join(os.getcwd(), '..'))
import utils.kmeans as kmeans

plotfile = '/home/administrator/plots/centroids/1742407201.json.gz'

centroids = kmeans.load_centroids(plotfile)
#print(centroids)
#kmeans.plot_heatmap(centroids)
kmeans.plot_heatmap(centroids)

# %%
_, centroids = kmeans.rearange_centroids(centroids, 2.0)
#print(centroids)
#kmeans.plot_heatmap(centroids)
kmeans.plot_heatmap(centroids)
