# %%
import sys, os
sys.path.append(os.path.join(os.getcwd(), '..'))
import utils.kmeans as kmeans

plotfile = '/home/ubuntu/anomdectests/centroids/1742504401.json.gz'

centroids = kmeans.load_centroids(plotfile)
#print(centroids)
#kmeans.plot_heatmap(centroids)
kmeans.plot_heatmap(centroids)

# %%
centroids, old_new_mapping = kmeans.rearange_centroids(centroids, 1.5)
print(old_new_mapping)
#kmeans.plot_heatmap(centroids)
kmeans.plot_heatmap(centroids)
# Out:
# {6: 0, 2: 0, 0: 0, 9: 0, 3: 0, 5: 0, 15: 0, 8: 1, 10: 1, 4: 1, 1: 1, 11: 1, 7: 1, 16: 1, 12: 2, 13: 2, 14: 2}
