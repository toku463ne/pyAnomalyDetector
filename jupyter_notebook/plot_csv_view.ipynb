# %%
import sys,os,json
sys.path.append(os.path.join(os.getcwd(), '..'))

import views

data_file = "../tests/test_detector_many.d/results_2nd.json"
with open(data_file, "r") as f:
    data = json.load(f)  

view_source = {
    "name": "test_detector_many",
    "type": "csv",
    "history_file_path": "../tests/testdata/csv/20250128/history.csv.gz",
    "trends_file_path": "../tests/testdata/csv/20250128/trends.csv.gz"
}

v = views.get_view(view_source)
v.show(data[view_source['name']])
