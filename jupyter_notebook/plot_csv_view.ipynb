# %%
import sys,os,json
sys.path.append(os.path.join(os.getcwd(), '..'))

import views

data_file = "../tests/test_zabbix.d/result.json"
with open(data_file, "r") as f:
    data = json.load(f)  

view_source = {
    "name": "test_zabbix",
    "type": "csv",
    "history_file_path": "../tests/testdata/csv/history.csv.gz",
    "trends_file_path": "../tests/testdata/csv/trends.csv.gz"
}

v = views.get_view(view_source)
v.show(data[view_source['name']])
