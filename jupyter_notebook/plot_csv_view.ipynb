# %%
import sys,os
import pandas as pd
sys.path.append(os.path.join(os.getcwd(), '..'))

import views

view_source = {
    "name": "views_20250214",
    "type": "csv",
    "history_file_path": "../tests/testdata/csv/20250214_1100/history.csv.gz",
    "trends_file_path": "../tests/testdata/csv/20250214_1100/trends.csv.gz"
}

itemIds = [255218,141917,236160]
df = pd.DataFrame(itemIds, columns=['itemid'])

v = views.get_view(view_source)
v.show(df)
