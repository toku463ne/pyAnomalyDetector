# %%
import sys,os
import pandas as pd
sys.path.append(os.path.join(os.getcwd(), '..'))

import views
history_file = os.path.join(os.environ['HOME'], 'git/pyAnomalyDetector/tests/testdata/csv/20250407_0830/history.csv.gz')
trends_file = os.path.join(os.environ['HOME'], 'git/pyAnomalyDetector/tests/testdata/csv/20250407_0830/trends.csv.gz')
view_source = {
    "name": "views_20250407",
    "type": "csv",
    "history_file_path": history_file,
    "trends_file_path": trends_file,
    "startep": 1743980400 - 3600 * 24 * 7,
    "endep": 1743980400
}

def plot_charts(itemIds):
    df = pd.DataFrame(itemIds, columns=['itemid'])
    v = views.get_view(view_source)
    v.show(df)

# %%
plot_charts([240282,240285,240286,240289])

plot_charts([256679,256681])

plot_charts([230565,230592,230593,230594,230595,230596,230597,230598,230599,230600,230618,230619,230620,230621,
           230622,230623,230624,230625,230626])
