# %%
import sys,os
import pandas as pd
sys.path.append(os.path.join(os.getcwd(), '..'))

import views
history_file = os.path.join(os.environ['HOME'], 'git/pyAnomalyDetector/tests/testdata/csv/20250410_0800/history.csv.gz')
trends_file = os.path.join(os.environ['HOME'], 'git/pyAnomalyDetector/tests/testdata/csv/20250410_0800/trends.csv.gz')
view_source = {
    "name": "views_2025010",
    "type": "csv",
    "history_file_path": history_file,
    "trends_file_path": trends_file,
    "startep": 1744236001 - 3600 * 24,
    "endep": 1744236001
}

def plot_charts(itemIds):
    df = pd.DataFrame(itemIds, columns=['itemid'])
    v = views.get_view(view_source)
    v.show(df)

# %%
plot_charts([227721,227722,227723,227724,227725])

plot_charts([142038,223147,226179,
             233863,233974,234653,235433,235439,236474,236605,240454,246279,360736])
